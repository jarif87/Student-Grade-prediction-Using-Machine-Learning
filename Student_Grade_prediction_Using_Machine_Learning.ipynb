# %% [markdown]
# # Regression stands for to model a target value based on independent variables and Linear Regression is used to find the relationship between dependent (y) and independent variable (x)
#
#
# ---
#
#
# *   Linear Regression is a supervised machine learning algorithm
#
# *   Always works with continuous value
#
# *   formula y=mx+c m=slope of line and c=intercept
#
# *   Main target for linear regression to find the best value for x and y

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score
# %matplotlib inline

# %% [markdown]
# # There are 33 columns:
#
# * school: student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# * sex: student's sex (binary: 'F' - female or 'M' - male)
#
# * age: student's age (numeric: from 15 to 22)
#
# * address: student's home address type (binary: 'U' - urban or 'R' - rural)
#
# * famsize: family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#
# * Pstatus: parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#
# * Medu: mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
#
# * Fedu: father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
#
# * Mjob: mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# * Fjob: father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# * reason: reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
#
# * guardian: student's guardian (nominal: 'mother', 'father' or 'other')
#
# * traveltime: home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# * studytime: weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# * failures: number of past class failures (numeric: n if 1<=n<3, else 4)
#
# * schoolsup: extra educational support (binary: yes or no)
#
# * famsup: family educational support (binary: yes or no)
#
# * paid: extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# * activities: extra-curricular activities (binary: yes or no)
#
# * nursery: attended nursery school (binary: yes or no)
#
# * higher: wants to take higher education (binary: yes or no)
#
# * internet: Internet access at home (binary: yes or no)
#
# * romantic: with a romantic relationship (binary: yes or no)
#
# * famrel: quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# * freetime: free time after school (numeric: from 1 - very low to 5 - very high)
#
# * goout: going out with friends (numeric: from 1 - very low to 5 - very high)
#
# * Dalc: workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# * Walc: weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# * health: current health status (numeric: from 1 - very bad to 5 - very good)
#
# * absences: number of school absences (numeric: from 0 to 93)
#
# * G1: first period grade (numeric: from 0 to 20)
#
# * G2: second period grade (numeric: from 0 to 20)
#
# * G3: final grade (numeric: from 0 to 20)

# %%
data=pd.read_csv("/content/student-mat.csv")

# %%
data.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.isnull().any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data.shape
# Out:
# (395, 33)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
#  19  nursery     395 non-null    object
#  20  higher      395 non-null    object
#  21  internet    395 non-null    object
#  22  romantic    395 non-null    object
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    int64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    int64
#  30  G1          395 non-null    int64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 102.0+ KB

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
cor_matrix=data.corr()

# %%
cor_matrix.style.background_gradient(cmap="Oranges_r")
# Out:
# <style type="text/css">
# #T_238d4_row0_col0, #T_238d4_row1_col1, #T_238d4_row2_col2, #T_238d4_row3_col3, #T_238d4_row4_col4, #T_238d4_row5_col5, #T_238d4_row6_col6, #T_238d4_row7_col7, #T_238d4_row8_col8, #T_238d4_row9_col9, #T_238d4_row10_col10, #T_238d4_row11_col11, #T_238d4_row12_col12, #T_238d4_row13_col13, #T_238d4_row14_col14, #T_238d4_row15_col15 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_238d4_row0_col1, #T_238d4_row4_col3, #T_238d4_row5_col6, #T_238d4_row12_col6, #T_238d4_row12_col11 {
#   background-color: #912e04;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col2, #T_238d4_row13_col3 {
#   background-color: #942f03;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col3, #T_238d4_row5_col7 {
#   background-color: #c64102;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col4, #T_238d4_row6_col2 {
#   background-color: #c34002;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col5 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col6, #T_238d4_row1_col7, #T_238d4_row3_col14, #T_238d4_row5_col11, #T_238d4_row8_col4, #T_238d4_row8_col13 {
#   background-color: #b03903;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col7, #T_238d4_row4_col0, #T_238d4_row4_col5, #T_238d4_row4_col6 {
#   background-color: #ab3803;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col8, #T_238d4_row5_col8, #T_238d4_row6_col14, #T_238d4_row8_col0 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col9, #T_238d4_row11_col10 {
#   background-color: #de4e05;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col10 {
#   background-color: #e15407;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col11, #T_238d4_row9_col6, #T_238d4_row15_col11 {
#   background-color: #892b04;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col12, #T_238d4_row5_col3, #T_238d4_row9_col15 {
#   background-color: #ce4401;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col13, #T_238d4_row11_col2 {
#   background-color: #c94202;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col14, #T_238d4_row7_col11, #T_238d4_row8_col6, #T_238d4_row9_col11 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_238d4_row0_col15, #T_238d4_row15_col6 {
#   background-color: #ae3903;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col0, #T_238d4_row1_col3, #T_238d4_row2_col0, #T_238d4_row4_col7, #T_238d4_row4_col9, #T_238d4_row4_col10, #T_238d4_row4_col12, #T_238d4_row5_col1, #T_238d4_row5_col2, #T_238d4_row5_col13, #T_238d4_row5_col14, #T_238d4_row5_col15, #T_238d4_row10_col4, #T_238d4_row10_col6, #T_238d4_row14_col5, #T_238d4_row14_col8, #T_238d4_row14_col11, #T_238d4_row15_col0, #T_238d4_row15_col5 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col2, #T_238d4_row2_col1 {
#   background-color: #fdc28b;
#   color: #000000;
# }
# #T_238d4_row1_col4, #T_238d4_row6_col7, #T_238d4_row10_col7, #T_238d4_row12_col9 {
#   background-color: #da4902;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col5, #T_238d4_row15_col12 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col6, #T_238d4_row2_col6, #T_238d4_row6_col9, #T_238d4_row8_col12 {
#   background-color: #9e3303;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col8, #T_238d4_row2_col4, #T_238d4_row2_col10, #T_238d4_row3_col13, #T_238d4_row4_col2, #T_238d4_row6_col8, #T_238d4_row9_col13, #T_238d4_row11_col7 {
#   background-color: #c14002;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col9 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col10, #T_238d4_row2_col9, #T_238d4_row3_col8, #T_238d4_row8_col15, #T_238d4_row9_col12 {
#   background-color: #b63c02;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col11, #T_238d4_row3_col12, #T_238d4_row9_col4, #T_238d4_row15_col3 {
#   background-color: #8c2c04;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col12, #T_238d4_row7_col0, #T_238d4_row10_col1, #T_238d4_row11_col1, #T_238d4_row11_col3, #T_238d4_row12_col4 {
#   background-color: #b13a03;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col13 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col14 {
#   background-color: #f57622;
#   color: #f1f1f1;
# }
# #T_238d4_row1_col15 {
#   background-color: #f67723;
#   color: #f1f1f1;
# }
# #T_238d4_row2_col3, #T_238d4_row13_col8 {
#   background-color: #812804;
#   color: #f1f1f1;
# }
# #T_238d4_row2_col5, #T_238d4_row2_col12, #T_238d4_row8_col11 {
#   background-color: #973003;
#   color: #f1f1f1;
# }
# #T_238d4_row2_col7 {
#   background-color: #a23503;
#   color: #f1f1f1;
# }
# #T_238d4_row2_col8, #T_238d4_row3_col15, #T_238d4_row12_col8 {
#   background-color: #bb3d02;
#   color: #f1f1f1;
# }
# #T_238d4_row2_col11, #T_238d4_row13_col10 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_238d4_row2_col13 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_238d4_row2_col14, #T_238d4_row7_col8 {
#   background-color: #f26c16;
#   color: #f1f1f1;
# }
# #T_238d4_row2_col15 {
#   background-color: #f16913;
#   color: #f1f1f1;
# }
# #T_238d4_row3_col0, #T_238d4_row9_col2, #T_238d4_row10_col14 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# #T_238d4_row3_col1 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# #T_238d4_row3_col2 {
#   background-color: #952f03;
#   color: #f1f1f1;
# }
# #T_238d4_row3_col4, #T_238d4_row13_col6 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_238d4_row3_col5, #T_238d4_row7_col5, #T_238d4_row14_col2 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_238d4_row3_col6, #T_238d4_row7_col4, #T_238d4_row11_col0 {
#   background-color: #9a3103;
#   color: #f1f1f1;
# }
# #T_238d4_row3_col7, #T_238d4_row6_col10, #T_238d4_row14_col7, #T_238d4_row14_col9 {
#   background-color: #a13403;
#   color: #f1f1f1;
# }
# #T_238d4_row3_col9, #T_238d4_row5_col9, #T_238d4_row6_col13, #T_238d4_row15_col4 {
#   background-color: #de5005;
#   color: #f1f1f1;
# }
# #T_238d4_row3_col10, #T_238d4_row12_col5, #T_238d4_row12_col10, #T_238d4_row14_col4 {
#   background-color: #e4580a;
#   color: #f1f1f1;
# }
# #T_238d4_row3_col11 {
#   background-color: #9c3203;
#   color: #f1f1f1;
# }
# #T_238d4_row4_col1, #T_238d4_row8_col1 {
#   background-color: #d64701;
#   color: #f1f1f1;
# }
# #T_238d4_row4_col8, #T_238d4_row13_col0, #T_238d4_row13_col9, #T_238d4_row14_col6 {
#   background-color: #993103;
#   color: #f1f1f1;
# }
# #T_238d4_row4_col11, #T_238d4_row13_col11 {
#   background-color: #852904;
#   color: #f1f1f1;
# }
# #T_238d4_row4_col13 {
#   background-color: #f26b15;
#   color: #f1f1f1;
# }
# #T_238d4_row4_col14 {
#   background-color: #ee6511;
#   color: #f1f1f1;
# }
# #T_238d4_row4_col15, #T_238d4_row7_col9 {
#   background-color: #ea5f0e;
#   color: #f1f1f1;
# }
# #T_238d4_row5_col0 {
#   background-color: #ec620f;
#   color: #f1f1f1;
# }
# #T_238d4_row5_col4 {
#   background-color: #932f03;
#   color: #f1f1f1;
# }
# #T_238d4_row5_col10, #T_238d4_row11_col5 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_238d4_row5_col12, #T_238d4_row15_col9 {
#   background-color: #a43503;
#   color: #f1f1f1;
# }
# #T_238d4_row6_col0, #T_238d4_row10_col12, #T_238d4_row11_col6 {
#   background-color: #be3f02;
#   color: #f1f1f1;
# }
# #T_238d4_row6_col1, #T_238d4_row7_col2, #T_238d4_row10_col2, #T_238d4_row11_col14 {
#   background-color: #c03f02;
#   color: #f1f1f1;
# }
# #T_238d4_row6_col3, #T_238d4_row7_col3, #T_238d4_row11_col8 {
#   background-color: #a83703;
#   color: #f1f1f1;
# }
# #T_238d4_row6_col4, #T_238d4_row6_col5 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_238d4_row6_col11, #T_238d4_row10_col11 {
#   background-color: #b93d02;
#   color: #f1f1f1;
# }
# #T_238d4_row6_col12, #T_238d4_row14_col0, #T_238d4_row14_col3 {
#   background-color: #842904;
#   color: #f1f1f1;
# }
# #T_238d4_row6_col15 {
#   background-color: #e35608;
#   color: #f1f1f1;
# }
# #T_238d4_row7_col1, #T_238d4_row9_col14 {
#   background-color: #cb4302;
#   color: #f1f1f1;
# }
# #T_238d4_row7_col6, #T_238d4_row8_col2 {
#   background-color: #d34601;
#   color: #f1f1f1;
# }
# #T_238d4_row7_col10, #T_238d4_row15_col2 {
#   background-color: #e75b0b;
#   color: #f1f1f1;
# }
# #T_238d4_row7_col12, #T_238d4_row13_col5 {
#   background-color: #802704;
#   color: #f1f1f1;
# }
# #T_238d4_row7_col13, #T_238d4_row7_col15, #T_238d4_row12_col1 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_238d4_row7_col14, #T_238d4_row9_col0 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_238d4_row8_col3, #T_238d4_row10_col13 {
#   background-color: #b83c02;
#   color: #f1f1f1;
# }
# #T_238d4_row8_col5, #T_238d4_row13_col1 {
#   background-color: #ee6410;
#   color: #f1f1f1;
# }
# #T_238d4_row8_col7

# %%
plt.figure(figsize=(15,15))
sns.heatmap(cor_matrix, annot = True,cmap="Purples")
plt.show()

# %%
data["G3"].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
plt.figure(figsize=(10,10))
b=sns.countplot(x=data["G3"])
b.axes.set_title("Final Grade Of a Student\n",fontsize=20)
b.set_xlabel("Final Grade")
b.set_ylabel("Count")
plt.show()

# %%
male_student=len(data[data["sex"]=="M"])
female_student=len(data[data["sex"]=="F"])

# %%
print(f"Number of Male Students   {male_student}")
# Out:
# Number of Male Students   187

# %%
print(f"Number of Female  Students   {female_student}")
# Out:
# Number of Female  Students   208

# %%
plt.figure(figsize=(10,10))
sns.countplot(x="age",hue="sex",data=data)
plt.title("Age Groups\n",fontsize=20,color="blue")
plt.show()

# %%
sns.countplot(x=data["address"])
plt.title("Urban Vs Rural Students\n",fontsize=20)
plt.show()

# %%
data.corr()['G3'].sort_values()
# Out:
# failures     -0.360415
# age          -0.161579
# goout        -0.132791
# traveltime   -0.117142
# health       -0.061335
# Dalc         -0.054660
# Walc         -0.051939
# freetime      0.011307
# absences      0.034247
# famrel        0.051363
# studytime     0.097820
# Fedu          0.152457
# Medu          0.217147
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64

# %%
data['GradeAvg'] = (data['G1'] + data['G2'] + data['G3']) / 3

# %%
data.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3   GradeAvg
# 0        3     4     1     1       3        6   5   6   6   5.666667
# 1        3     3     1     1       3        4   5   5   6   5.333333
# 2        3     2     2     3       3       10   7   8  10   8.333333
# 3        2     2     1     1       5        2  15  14  15  14.666667
# 4        3     2     1     2       5        4   6  10  10   8.666667
#
# [5 rows x 34 columns]

# %%
data.drop(["school","age"], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['sex', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'traveltime', 'studytime', 'failures',
#        'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher',
#        'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc',
#        'health', 'absences', 'G1', 'G2', 'G3', 'GradeAvg'],
#       dtype='object')

# %%
data.head()
# Out:
#   sex address famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason guardian  \
# 0   F       U     GT3       A     4     4  at_home   teacher  course   mother
# 1   F       U     GT3       T     1     1  at_home     other  course   father
# 2   F       U     LE3       T     1     1  at_home     other   other   mother
# 3   F       U     GT3       T     4     2   health  services    home   mother
# 4   F       U     GT3       T     3     3    other     other    home   father
#
#    ...  freetime  goout  Dalc Walc health absences  G1  G2  G3   GradeAvg
# 0  ...         3      4     1    1      3        6   5   6   6   5.666667
# 1  ...         3      3     1    1      3        4   5   5   6   5.333333
# 2  ...         3      2     2    3      3       10   7   8  10   8.333333
# 3  ...         2      2     1    1      5        2  15  14  15  14.666667
# 4  ...         3      2     1    2      5        4   6  10  10   8.666667
#
# [5 rows x 32 columns]

# %%
data_dum=data

# %%
#Converting to categorical value
categorical_d = {'yes': 1, 'no': 0}
data_dum['schoolsup'] = data_dum['schoolsup'].map(categorical_d)
data_dum['famsup'] = data_dum['famsup'].map(categorical_d)
data_dum['paid'] = data_dum['paid'].map(categorical_d)
data_dum['activities'] = data_dum['activities'].map(categorical_d)
data_dum['nursery'] = data_dum['nursery'].map(categorical_d)
data_dum['higher'] = data_dum['higher'].map(categorical_d)
data_dum['internet'] = data_dum['internet'].map(categorical_d)
data_dum['romantic'] = data_dum['romantic'].map(categorical_d)

# %%
categorical_d = {'F': 1, 'M': 0}
data_dum['sex'] = data_dum['sex'].map(categorical_d)

# map the address data
categorical_d = {'U': 1, 'R': 0}
data_dum['address'] = data_dum['address'].map(categorical_d)

# map the famili size data
categorical_d = {'LE3': 1, 'GT3': 0}
data_dum['famsize'] = data_dum['famsize'].map(categorical_d)

# map the parent's status
categorical_d= {'T': 1, 'A': 0}
data_dum['Pstatus'] = data_dum['Pstatus'].map(categorical_d)

# map the parent's job
categorical_d = {'teacher': 0, 'health': 1, 'services': 2,'at_home': 3,'other': 4}
data_dum['Mjob'] = data_dum['Mjob'].map(categorical_d)
data_dum['Fjob'] = data_dum['Fjob'].map(categorical_d)

# map the reason data
categorical_d= {'home': 0, 'reputation': 1, 'course': 2,'other': 3}
data_dum['reason'] = data_dum['reason'].map(categorical_d)

# map the guardian data
categorical_d = {'mother': 0, 'father': 1, 'other': 2}
data_dum['guardian'] = data_dum['guardian'].map(categorical_d)

# %%
data_dum.columns
# Out:
# Index(['sex', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'traveltime', 'studytime', 'failures',
#        'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher',
#        'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc',
#        'health', 'absences', 'G1', 'G2', 'G3', 'GradeAvg'],
#       dtype='object')

# %%
len(data_dum.columns)
# Out:
# 32

# %%
data_dum['G3']
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 395, dtype: int64

# %%
data_dum.head(5)
# Out:
#    sex  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  guardian  \
# 0    1        1        0        0     4     4     3     0       2         0
# 1    1        1        0        1     1     1     3     4       2         1
# 2    1        1        1        1     1     1     3     4       3         0
# 3    1        1        0        1     4     2     1     2       0         0
# 4    1        1        0        1     3     3     4     4       0         1
#
#    ...  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3   GradeAvg
# 0  ...         3      4     1     1       3         6   5   6   6   5.666667
# 1  ...         3      3     1     1       3         4   5   5   6   5.333333
# 2  ...         3      2     2     3       3        10   7   8  10   8.333333
# 3  ...         2      2     1     1       5         2  15  14  15  14.666667
# 4  ...         3      2     1     2       5         4   6  10  10   8.666667
#
# [5 rows x 32 columns]

# %%
train_data=data_dum.drop("G3",axis=1)
label_data=data_dum['G3']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train_data,label_data, test_size = 0.8, random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(X_test)

# %%
pred
# Out:
# array([ 1.00000000e+01,  1.20000000e+01,  5.00000000e+00,  1.00000000e+01,
#         9.00000000e+00,  1.30000000e+01,  1.80000000e+01,  6.00000000e+00,
#         8.88178420e-15,  1.40000000e+01,  1.50000000e+01,  7.00000000e+00,
#         1.50000000e+01,  1.00000000e+01,  1.40000000e+01,  8.00000000e+00,
#         8.00000000e+00,  1.10000000e+01,  1.50000000e+01,  1.24344979e-14,
#         1.40000000e+01,  1.60000000e+01,  1.60000000e+01,  6.00000000e+00,
#         1.59872116e-14,  1.90000000e+01,  1.10000000e+01,  1.20000000e+01,
#         1.70000000e+01,  1.00000000e+01,  8.00000000e+00,  1.00000000e+01,
#         1.50000000e+01,  1.30000000e+01,  8.00000000e+00,  5.00000000e+00,
#         5.41788836e-14,  1.50000000e+01,  1.40000000e+01,  8.00000000e+00,
#         5.00000000e+00,  1.10000000e+01,  1.40000000e+01,  9.00000000e+00,
#         1.50000000e+01,  1.00000000e+01,  1.10000000e+01,  1.30000000e+01,
#         1.30000000e+01,  1.60000000e+01,  1.30000000e+01,  1.50000000e+01,
#         1.20000000e+01,  1.00000000e+01,  6.00000000e+00,  1.20000000e+01,
#         1.10000000e+01,  2.66453526e-14,  1.60000000e+01,  1.70000000e+01,
#         1.40000000e+01,  1.00000000e+01,  1.00000000e+01,  6.00000000e+00,
#         9.00000000e+00,  1.70000000e+01,  8.00000000e+00,  1.00000000e+01,
#         9.00000000e+00,  1.50000000e+01,  6.00000000e+00,  1.00000000e+01,
#         1.50000000e+01,  1.90000000e+01,  1.20000000e+01,  6.00000000e+00,
#         9.00000000e+00,  1.50000000e+01,  5.00000000e+00,  1.20000000e+01,
#         1.40000000e+01,  2.66453526e-14,  9.00000000e+00,  8.00000000e+00,
#         7.00000000e+00,  1.40000000e+01,  4.44089210e-14,  1.20000000e+01,
#         1.50000000e+01,  3.19744231e-14,  1.30000000e+01,  9.00000000e+00,
#         1.10000000e+01,  1.00000000e+01,  3.37507799e-14,  8.00000000e+00,
#         1.00000000e+01,  1.80000000e+01,  1.90000000e+01,  1.40000000e+01,
#         1.20000000e+01,  1.30000000e+01,  6.00000000e+00,  1.00000000e+01,
#         1.00000000e+01,  8.00000000e+00,  1.00000000e+01,  8.00000000e+00,
#         9.00000000e+00, -1.77635684e-15,  7.00000000e+00,  5.00000000e+00,
#         1.10000000e+01,  5.00000000e+00,  1.00000000e+01,  1.80000000e+01,
#         8.00000000e+00,  8.00000000e+00,  1.60000000e+01,  1.00000000e+01,
#         1.20000000e+01,  8.00000000e+00,  1.10000000e+01,  1.60000000e+01,
#         1.10000000e+01,  1.20000000e+01,  1.30000000e+01,  1.59872116e-14,
#         3.90798505e-14,  8.00000000e+00,  1.20000000e+01,  1.00000000e+01,
#         1.30000000e+01,  3.73034936e-14,  1.80000000e+01,  1.50000000e+01,
#         1.59872116e-14,  1.10000000e+01,  1.80000000e+01,  1.20000000e+01,
#         1.00000000e+01,  1.30000000e+01,  1.00000000e+01,  1.60000000e+01,
#         1.00000000e+01,  1.10000000e+01,  1.50000000e+01,  1.10000000e+01,
#         1.10000000e+01,  1.40000000e+01,  3.01980663e-14,  9.00000000e+00,
#         8.00000000e+00,  6.00000000e+00,  1.10000000e+01,  1.10000000e+01,
#         1.30000000e+01,  1.00000000e+01,  1.40000000e+01,  1.00000000e+01,
#         8.00000000e+00,  7.00000000e+00,  6.00000000e+00,  1.10000000e+01,
#         1.70000000e+01,  6.00000000e+00,  1.60000000e+01,  1.30000000e+01,
#         1.50000000e+01,  1.30000000e+01,  1.60000000e+01,  1.00000000e+01,
#         9.00000000e+00,  8.00000000e+00,  1.20000000e+01,  1.50000000e+01,
#         4.35207426e-14,  1.30000000e+01,  6.00000000e+00,  8.00000000e+00,
#         1.00000000e+01,  1.20000000e+01,  1.10000000e+01,  8.00000000e+00,
#         1.20000000e+01,  2.66453526e-14,  1.20000000e+01,  6.00000000e+00,
#         3.64153152e-14,  1.00000000e+01,  1.95399252e-14,  1.50000000e+01,
#         1.00000000e+01,  1.40000000e+01,  8.00000000e+00,  6.00000000e+00,
#         1.10000000e+01,  1.30000000e+01,  8.00000000e+00,  1.80000000e+01,
#         1.10000000e+01,  1.20000000e+01,  1.00000000e+01,  1.10000000e+01,
#         1.30000000e+01,  1.30000000e+01,  1.10000000e+01,  1.70000000e+01,
#         9.00000000e+00,  1.30000000e+01,  1.50000000e+01,  9.00000000e+00,
#         1.00000000e+01,  1.00000000e+01,  1.10000000e+01,  7.00000000e+00,
#         8.00000000e+00,  2.30926389e-14,  1.20000000e+01,  1.00000000e+01,
#         1.00000000e+01,  4.08562073e-14,  1.00000000e+01,  1.10000000e+01,
#         1.60000000e+01,  9.00000000e+00,  1.10000000e+01,  1.10000000e+01,
#         1.50000000e+01,  1.40000000e+01,  1.40000000e+01,  1.20000000e+01,
#         1.70000000e+01,  1.30000000e+01,  1.10000000e+01,  9.00000000e+00,
#         1.10000000e+01,  1.00000000e+01,  1.10000000e+01,  1.50000000e+01,
#         1.60000000e+01,  1.80000000e+01,  9.00000000e+00,  1.24344979e-14,
#         1.10000000e+01,  4.52970994e-14,  1.20000000e+01,  1.90000000e+01,
#         9.00000000e+00,  1.00000000e+01,  1.50000000e+01,  1.30000000e+01,
#         8.00000000e+00,  3.37507799e-14,  1.10000000e+01,  1.50000000e+01,
#         1.20000000e+01,  1.40000000e+01,  6.00000000e+00,  1.10000000e+01,
#         2.13162821e-14,  1.10000000e+01,  1.30000000e+01,  1.00000000e+01,
#         3.01980663e-14,  1.00000000e+01,  1.30000000e+01,  1.20000000e+01,
#         1.40000000e+01,  1.20000000e+01,  9.00000000e+00,  1.20000000e+01,
#         8.00000000e+00,  7.00000000e+00,  1.20000000e+01,  1.00000000e+01,
#         1.00000000e+01,  1.30000000e+01,  8.00000000e+00,  5.00000000e+00,
#         1.50000000e+01,  2.30926389e-14,  8.00000000e+00,  1.60000000e+01,
#         1.40000000e+01,  1.50000000e+01,  1.10000000e+01,  2.00000000e+01,
#         1.60000000e+01,  1.10000000e+01,  1.60000000e+01,  1.30000000e+01,
#         1.50000000e+01,  1.50000000e+01,  1.40000000e+01,  1.80000000e+01,
#         1.40000000e+01,  3.19744231e-14,  1.50000000e+01,  1.20000000e+01,
#         9.00000000e+00,  1.95399252e-14,  3.01980663e-14,  1.90000000e+01,
#         1.00000000e+01,  1.10000000e+01,  1.60000000e+01,  1.30000000e+01,
#         1.10000000e+01,  1.20000000e+01,  1.10000000e+01,  4.00000000e+00,
#         1.00000000e+01, -8.88178420e-15,  1.30000000e+01,  1.30000000e+01])

# %% [markdown]
# # Model Test Score

# %%
model.score(X_test,Y_test)
# Out:
# 1.0

# %% [markdown]
# # Model Training Score

# %%
model.score(X_train,Y_train)
# Out:
# 1.0

# %%
plt.figure(figsize=(10,10))
plt.scatter(pred,Y_test,marker="*",s=50,color="green")
plt.grid(True)
plt.show()

# %% [markdown]
# # residual data

# %%
residual_data=Y_test-pred

# %%
plt.figure(figsize=(10,10))
plt.scatter(pred,residual_data,marker=".",s=80,color="indigo")

plt.show()

# %%
sns.displot(residual_data,kde=True,height=10,color="brown")
plt.show()

# %% [markdown]
# # R2 Score

# %%
r2_score(Y_test,pred)
# Out:
# 1.0

# %% [markdown]
# # Mean Square Error

# %%
mean_squared_error(Y_test,pred)
# Out:
# 5.477590500746659e-28
